# %%
import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
pdf_file = open('pdf.pdf','rb')

# %%
pdf_reader  = PyPDF2.PdfFileReader(pdf_file)

# %%
#discerning the number of pages will allow us to parse through all #the pages
num_pages = pdf_reader.numPages
count = 0
text = ""
#The while loop will read each page
while count < num_pages:
    pageObj = pdf_reader.getPage(count)
    count +=1
    text += pageObj.extractText()
#This if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.
if text != "":
    text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text
else:
    text = textract.process('pdf.pdf', method='tesseract')

# %%
#The word_tokenize() function will break our text phrases into #individual words
tokens = word_tokenize(str(text))
#we'll create a new list which contains punctuation we wish to clean
punctuations = ['(',')',';',':','[',']',',','.','...','..']
#We initialize the stopwords variable which is a list of words like #"The", "I", "and", etc. that don't hold much value as keywords
stop_words = stopwords.words('english')
#We create a list comprehension which only returns a list of words #that are NOT IN stop_words and NOT IN punctuations.
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
import re
from nltk.util import ngrams
s = str(text)
s = s.strip()
s = s.lower()
s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
tokens = [token for token in s.split(" ") if token != ""]
output = list(ngrams(tokens, 2))

# %%
s = str(text,'UTF')
s = s.strip('\n')
s = s.rstrip()
s = s.lower()
s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
tokens = [token for token in s.split(" ") if token != ""]
output = list(ngrams(tokens, 2))

# %%
import pandas as pd
df = pd.DataFrame(output)

# %%
text
# Out:
# b'monetha\n\nWhite paper\n\nJune, 2017\n\x0cExecutive summary 2\n\n1. Three significant problems that merchants face: trust and reputation, payments,\n\nand an inability to reach the growing Ethereum economy 4\n1.1 Trust and reputation problem in global e-commerce 5\n1.2 Expensive and long payment process 7\n1.3 An inability to participate in token-enabled digital asset economy potentially worth\n$10T in 2025. 9\n2. Monetha\xe2\x80\x99s solution: a decentralized trust and reputation system working flawlessly\ntogether through a blockchain based payment gateway 10\n2.1 A Universal Decentralized Trust and Reputation System on the Ethereum blockchain.\nEnsuring trust in global commerce. 11\n2.2 A mobile payments solution to accept mobile Ethereum based cryptocurrency\npayments generally up to 5X cheaper and up to x10000 faster. 15\n2.3 Enabling merchants to reach $10 trillion digital asset economy 18\n3. Product architecture and product development timeline 21\n3.1 Smart Contracts & Workflows 21\n3.2 Intended Product architecture 24\n3.3 Beta version of the product 24\n3.4 Product development roadmap. 25\n4. Market opportunity and business model 27\n4.1 Market opportunity 28\n4.2 Business model 32\n5. Marketing and Strategy 33\n5.1 Network effect 33\n5.2 Loyalty program 34\n6. Crowdsale details 36\n6.1 MTH Creation Ratios 37\n1st price batch until the soft cap is reached: 1 ETH = 2400 MTH 37\n2rd price batch after the soft cap is reached: 1 ETH = 2000 MTH. 37\n6.2 MTH Tokens 38\n6.3 Incentive program 38\n6.4 Budget 39\n7. Legal 40\n8. Team 43\n8.1 Monetha Team 43\n8.2 Monetha Advisory Team 45\nReferences 47\n\x0cExecutive summary\n\nE-commerce worldwide sales in 2014 were USD 1.33 trillion and are projected to\nincrease to USD 4.058 trillion by 2020. E-commerce share of retail sales is expected\nto increase from 7.4% in 2015 to 14.6% in 2020. Furthermore, according to Statista,\nthe number of people buying goods or services online will increase from 1.46 billion\nin 2015 to above 2 billion in 2020.\n\nDespite the explosive growth, three major problems still exist:\n\n1. Trust and reputation: Building trust is difficult, and it is centrally governed by\nbig marketplaces. There is an inability to transfer trust from one centralized\nservice to another, and thus a need to establish relationship with each\nmerchant separately. Moreover, a merchant\'s history is not recorded, so there\nis no ability to punish fraudulent buyers or merchants. Huge efforts and\nadvertising budgets are needed to create trust if a merchant is not a part of a\ncentralized marketplace.\n\n2. Expensive and long payment process: There are 16(!) different steps to\nsettle the transaction and up to 15(!) different fees to pay for payment\ngateways. Transaction fees range from 2% + 0.1 to 6% + 0.7. Chargeback\nfees of USD 15. Moreover, existing payment gateways rarely offer a simple\nsolution for a merchant to accept mobile payments on their website or point of\nsale terminals.\n\n3. An inability to reach the growing ethereum economy: Today, merchants\ncannot accept payments in Ether, which has reached a market cap of USD\n36bn as of June 14th. Moreover, a totally new digital asset class is being\ncreated: tokens of products that are built on the Ethereum platform. The rise\nof a new kind of digital assets enables the creation of a token-based digital\nasset economy. It is expected that 10% of global GDP will be generated on\nblockchains by 2025. Merchants will definitely want to participate in the\nblockchain created economy.\n\nMonetha is creating a universal decentralized trust and reputation solution\nworking flawlessly together with mobile payments processing on the\nEthereum blockchain leveraging smart contract technology.\n\n1. Universal/Transferable trust and reputation system: Every time a\n\ntransaction is made the blockchain will record the time of the transaction, both\nreceiving and sending wallet addresses, warranty conditions, delivery time,\n\nM\n ...

# %%
s
# Out:
# 'monetha\n\nwhite paper\n\njune  2017\n\x0cexecutive summary 2\n\n1  three significant problems that merchants face  trust and reputation  payments \n\nand an inability to reach the growing ethereum economy 4\n1 1 trust and reputation problem in global e commerce 5\n1 2 expensive and long payment process 7\n1 3 an inability to participate in token enabled digital asset economy potentially worth\n 10t in 2025  9\n2  monetha s solution  a decentralized trust and reputation system working flawlessly\ntogether through a blockchain based payment gateway 10\n2 1 a universal decentralized trust and reputation system on the ethereum blockchain \nensuring trust in global commerce  11\n2 2 a mobile payments solution to accept mobile ethereum based cryptocurrency\npayments generally up to 5x cheaper and up to x10000 faster  15\n2 3 enabling merchants to reach  10 trillion digital asset economy 18\n3  product architecture and product development timeline 21\n3 1 smart contracts   workflows 21\n3 2 intended product architecture 24\n3 3 beta version of the product 24\n3 4 product development roadmap  25\n4  market opportunity and business model 27\n4 1 market opportunity 28\n4 2 business model 32\n5  marketing and strategy 33\n5 1 network effect 33\n5 2 loyalty program 34\n6  crowdsale details 36\n6 1 mth creation ratios 37\n1st price batch until the soft cap is reached  1 eth   2400 mth 37\n2rd price batch after the soft cap is reached  1 eth   2000 mth  37\n6 2 mth tokens 38\n6 3 incentive program 38\n6 4 budget 39\n7  legal 40\n8  team 43\n8 1 monetha team 43\n8 2 monetha advisory team 45\nreferences 47\n\x0cexecutive summary\n\ne commerce worldwide sales in 2014 were usd 1 33 trillion and are projected to\nincrease to usd 4 058 trillion by 2020  e commerce share of retail sales is expected\nto increase from 7 4  in 2015 to 14 6  in 2020  furthermore  according to statista \nthe number of people buying goods or services online will increase from 1 46 billion\nin 2015 to above 2 billion in 2020 \n\ndespite the explosive growth  three major problems still exist \n\n1  trust and reputation  building trust is difficult  and it is centrally governed by\nbig marketplaces  there is an inability to transfer trust from one centralized\nservice to another  and thus a need to establish relationship with each\nmerchant separately  moreover  a merchant s history is not recorded  so there\nis no ability to punish fraudulent buyers or merchants  huge efforts and\nadvertising budgets are needed to create trust if a merchant is not a part of a\ncentralized marketplace \n\n2  expensive and long payment process  there are 16    different steps to\nsettle the transaction and up to 15    different fees to pay for payment\ngateways  transaction fees range from 2    0 1 to 6    0 7  chargeback\nfees of usd 15  moreover  existing payment gateways rarely offer a simple\nsolution for a merchant to accept mobile payments on their website or point of\nsale terminals \n\n3  an inability to reach the growing ethereum economy  today  merchants\ncannot accept payments in ether  which has reached a market cap of usd\n36bn as of june 14th  moreover  a totally new digital asset class is being\ncreated  tokens of products that are built on the ethereum platform  the rise\nof a new kind of digital assets enables the creation of a token based digital\nasset economy  it is expected that 10  of global gdp will be generated on\nblockchains by 2025  merchants will definitely want to participate in the\nblockchain created economy \n\nmonetha is creating a universal decentralized trust and reputation solution\nworking flawlessly together with mobile payments processing on the\nethereum blockchain leveraging smart contract technology \n\n1  universal transferable trust and reputation system  every time a\n\ntransaction is made the blockchain will record the time of the transaction  both\nreceiving and sending wallet addresses  warranty conditions  delivery time \n\nm\n\x0cand all o ...

# %%
s
# Out:
# 'b monetha n nwhite paper n njune  2017 n x0cexecutive summary 2 n n1  three significant problems that merchants face  trust and reputation  payments  n nand an inability to reach the growing ethereum economy 4 n1 1 trust and reputation problem in global e commerce 5 n1 2 expensive and long payment process 7 n1 3 an inability to participate in token enabled digital asset economy potentially worth n 10t in 2025  9 n2  monetha xe2 x80 x99s solution  a decentralized trust and reputation system working flawlessly ntogether through a blockchain based payment gateway 10 n2 1 a universal decentralized trust and reputation system on the ethereum blockchain  nensuring trust in global commerce  11 n2 2 a mobile payments solution to accept mobile ethereum based cryptocurrency npayments generally up to 5x cheaper and up to x10000 faster  15 n2 3 enabling merchants to reach  10 trillion digital asset economy 18 n3  product architecture and product development timeline 21 n3 1 smart contracts   workflows 21 n3 2 intended product architecture 24 n3 3 beta version of the product 24 n3 4 product development roadmap  25 n4  market opportunity and business model 27 n4 1 market opportunity 28 n4 2 business model 32 n5  marketing and strategy 33 n5 1 network effect 33 n5 2 loyalty program 34 n6  crowdsale details 36 n6 1 mth creation ratios 37 n1st price batch until the soft cap is reached  1 eth   2400 mth 37 n2rd price batch after the soft cap is reached  1 eth   2000 mth  37 n6 2 mth tokens 38 n6 3 incentive program 38 n6 4 budget 39 n7  legal 40 n8  team 43 n8 1 monetha team 43 n8 2 monetha advisory team 45 nreferences 47 n x0cexecutive summary n ne commerce worldwide sales in 2014 were usd 1 33 trillion and are projected to nincrease to usd 4 058 trillion by 2020  e commerce share of retail sales is expected nto increase from 7 4  in 2015 to 14 6  in 2020  furthermore  according to statista  nthe number of people buying goods or services online will increase from 1 46 billion nin 2015 to above 2 billion in 2020  n ndespite the explosive growth  three major problems still exist  n n1  trust and reputation  building trust is difficult  and it is centrally governed by nbig marketplaces  there is an inability to transfer trust from one centralized nservice to another  and thus a need to establish relationship with each nmerchant separately  moreover  a merchant  s history is not recorded  so there nis no ability to punish fraudulent buyers or merchants  huge efforts and nadvertising budgets are needed to create trust if a merchant is not a part of a ncentralized marketplace  n n2  expensive and long payment process  there are 16    different steps to nsettle the transaction and up to 15    different fees to pay for payment ngateways  transaction fees range from 2    0 1 to 6    0 7  chargeback nfees of usd 15  moreover  existing payment gateways rarely offer a simple nsolution for a merchant to accept mobile payments on their website or point of nsale terminals  n n3  an inability to reach the growing ethereum economy  today  merchants ncannot accept payments in ether  which has reached a market cap of usd n36bn as of june 14th  moreover  a totally new digital asset class is being ncreated  tokens of products that are built on the ethereum platform  the rise nof a new kind of digital assets enables the creation of a token based digital nasset economy  it is expected that 10  of global gdp will be generated on nblockchains by 2025  merchants will definitely want to participate in the nblockchain created economy  n nmonetha is creating a universal decentralized trust and reputation solution nworking flawlessly together with mobile payments processing on the nethereum blockchain leveraging smart contract technology  n n1  universal transferable trust and reputation system  every time a n ntransaction is made the blockchain will record the time of the transaction  both nreceiving and sending wallet addresses  warranty conditions  delivery time  n nm  ...
