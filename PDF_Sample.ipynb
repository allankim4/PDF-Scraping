# %%
import PyPDF2 
import textract
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
pdf_file = open('dream-speech.pdf','rb')

# %%
pdf_reader  = PyPDF2.PdfFileReader(pdf_file)

# %%
#discerning the number of pages will allow us to parse through all #the pages
num_pages = pdf_reader.numPages
count = 0
text = ""
#The while loop will read each page
while count < num_pages:
    pageObj = pdf_reader.getPage(count)
    count +=1
    text += pageObj.extractText()
#This if statement exists to check if the above library returned #words. It's done because PyPDF2 cannot read scanned files.
if text != "":
    text = text
#If the above returns as False, we run the OCR library textract to #convert scanned/image based PDF files into text
else:
    text = textract.process('pdf.pdf', method='tesseract')

# %%
#The word_tokenize() function will break our text phrases into #individual words
tokens = word_tokenize(str(text))
#we'll create a new list which contains punctuation we wish to clean
punctuations = ['(',')',';',':','[',']',',','.','...','..']
#We initialize the stopwords variable which is a list of words like #"The", "I", "and", etc. that don't hold much value as keywords
stop_words = stopwords.words('english')
#We create a list comprehension which only returns a list of words #that are NOT IN stop_words and NOT IN punctuations.
keywords = [word for word in tokens if not word in stop_words and not word in punctuations]

# %%
import re
from nltk.util import ngrams
s = str(text)
s = s.strip()
s = s.lower()
s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
tokens = [token for token in s.split(" ") if token != ""]
output = list(ngrams(tokens, 2))

# %%
s = str(text)
s = s.strip('\n')
s = s.rstrip()
s = s.lower()
s = re.sub(r'[^a-zA-Z0-9\s]', ' ', s)
tokens = [token for token in s.split(" ") if token != ""]
output = list(ngrams(tokens, 2))

# %%
import pandas as pd
df = pd.DataFrame(output)

# %%
text
# Out:
# '"I HAVE A DREAM ..." (Copyright 1963, MARTIN LtrTHER KING, JR.) Speooh by the Rev. MARTIN LuTHER KING At the "March on vYashington" I am happy to join with you today in what will go down in history as the greatesŁt demonstration for freedom in the history of our nation. Five years ago a great American in whose holic shado·w we stand today signed the Emancipation Proclamation. This momen:tous cleeree is a great beacon light of hope to millions of Negro slave·s who had been in the flames o[ withering injushcc. It came as a joyous daybre,ak to end the long night of their captivity. But 100 years late<r the Negro still is noŁt fre·e. One dred years later the 1i.fe of the Negro is still badly erippled by the manacles of s-tŁgrPg-ation and the chains of discriminatio11. One hnndred years later the Ne,gro live·s on a lone,Jy i:"]and of poverty in the mids1t of a va1S1t ooean of matE>.rial prospc·rity. Out> hundred years later the egro is still iu the o.f Ame·rican and find;:; himself in exile in his own land. So wo\'\'\'<\' come hf\'rP torlay to r1r.amatize a s,hameful condition. In a sense we\'ve come to our nation\'s capital to cash a eheck. Whrn the a. rebit ects of our Re:publie wrote the magnificent. wonls of the Constitution a.nd the Declaration o1 Independence, they we·re signing· a promiss\'Cl<ry note to which eve·ry American wa:" to fall heir. \'I\'his no,te was a promise that all nwn-yc::;, bla,ek men as we11 as white rmm-wonld he g1mnmtPt\'d the unalienable rights of life, liherty a]l(l the pnrsni1 of ha.ppine\'Ss. It is obvious today tha.t Amcri(·a lms <lcfaulted on this promissory note far as hP>r citi7.ens of co.Jo,r arr concP:rned. Instead of honoring ih1s sacn\'d ohli,gation, America ha.s given the Nngro p0ople a bad check, a check which has come back marked \'\'insufficient fnnds.\'\' But we refus.e to helieve that the bank of justice is bankrupt. We rp.fnse to t.ha.t there are insufficient fuwls in the grea.t vaults of opportunity orf this nation. So we\'ve come to cash this check, a check that will give ns upon oemand the rirhes of freedom and the s·ecurity of justice. \\Ve haYe a.bo come to this hallowed spot to remind Ame.rica of the fipJ·ce urgency of now. \'l\'hi:-; is no time to l\'llgagc in the luxury of cooling off or to t.ake the quilizing dmg of graduali::;m. Now is the time to make real the of democracy. Now is the time to rise from the dark nnll clrsolate valley of segregation to the ,.unlit path of racial justi<·P. Now is the time to li.ft our uation from the quicksands of raeial injustice to the solid r()ek of brotherhood. Xow is t.he time to mak0 justice a reality for all of God\'s children. It would be fatal for the nation to look the urgency of the moment. This swelt.ering summer of the i\\eg:ro\'s legitimate disconte.nt. will not pass until there is .an invigorating autumn of freedom and equality -1963 is not an (md but a beginning. Tho>se who hope that tl1e Xegro needed to hlow off steam and will now be l\'Olltent will ha\\·e a ruoP awakening if the na:tion return1\'1 to as usua.I. \'l\'here will be 11eitht\'T rest nor tranquility in Ame.rica until the Negro granted his citizenship rights. The whirlwinds of revolt will continue to shake the tions of onr nation until the bright days of justice emerge. (Copyright 101i3, MARTI:-< Lt:THFR KIKc, JR.) And that is something that I mus.t say to my pBople who o.n the worn threshold whieh leads into the palace of justice. In the process of gaining our rightful place we must not he guilty of wrongful deeds. Let us not "eek to sati:sfy our thirst for freedom by drinking from the cup of biMe·n:le·s,s a.nd hatred. \\Ve must forever conduct our s.truggle on the high plane of dignity and diseiplin e. \\Ye must not allow our tive protests to degen e·rate into physical violence. Again and again we must ri se to the maje,stic heights of meding physical fo.rce wi.th soul for-ce. rl\'he marvelous new tancy whi-ch has cn.gulfE>d the Negro community must not lead us to ...

# %%
s
# Out:
# ' i have a dream       copyright 1963  martin ltrther king  jr   speooh by the rev  martin luther king at the  march on vyashington  i am happy to join with you today in what will go down in history as the greates t demonstration for freedom in the history of our nation  five years ago a great american in whose holic shado w we stand today signed the emancipation proclamation  this momen tous cleeree is a great beacon light of hope to millions of negro slave s who had been in the flames o  withering injushcc  it came as a joyous daybre ak to end the long night of their captivity  but 100 years late r the negro still is no t fre e  one dred years later the 1i fe of the negro is still badly erippled by the manacles of s t grpg ation and the chains of discriminatio11  one hnndred years later the ne gro live s on a lone jy i   and of poverty in the mids1t of a va1s1t ooean of mate  rial prospc rity  out  hundred years later the egro is still iu the o f ame rican and find    himself in exile in his own land  so wo      come hf rp torlay to r1r amatize a s hameful condition  in a sense we ve come to our nation s capital to cash a eheck  whrn the a  rebit ects of our re publie wrote the magnificent  wonls of the constitution a nd the declaration o1 independence  they we re signing  a promiss cl ry note to which eve ry american wa   to fall heir   i his no te was a promise that all nwn yc     bla ek men as we11 as white rmm wonld he g1mnmtpt d the unalienable rights of life  liherty a l l the pnrsni1 of ha ppine ss  it is obvious today tha t amcri  a lms  lcfaulted on this promissory note far as hp r citi7 ens of co jo r arr concp rned  instead of honoring ih1s sacn d ohli gation  america ha s given the nngro p0ople a bad check  a check which has come back marked   insufficient fnnds    but we refus e to helieve that the bank of justice is bankrupt  we rp fnse to t ha t there are insufficient fuwls in the grea t vaults of opportunity orf this nation  so we ve come to cash this check  a check that will give ns upon oemand the rirhes of freedom and the s ecurity of justice   ve haye a bo come to this hallowed spot to remind ame rica of the fipj ce urgency of now   l hi    is no time to l llgagc in the luxury of cooling off or to t ake the quilizing dmg of graduali   m  now is the time to make real the of democracy  now is the time to rise from the dark nnll clrsolate valley of segregation to the   unlit path of racial justi  p  now is the time to li ft our uation from the quicksands of raeial injustice to the solid r  ek of brotherhood  xow is t he time to mak0 justice a reality for all of god s children  it would be fatal for the nation to look the urgency of the moment  this swelt ering summer of the i eg ro s legitimate disconte nt  will not pass until there is  an invigorating autumn of freedom and equality  1963 is not an  md but a beginning  tho se who hope that tl1e xegro needed to hlow off steam and will now be l olltent will ha  e a ruop awakening if the na tion return1 1 to as usua i   l here will be 11eitht t rest nor tranquility in ame rica until the negro granted his citizenship rights  the whirlwinds of revolt will continue to shake the tions of onr nation until the bright days of justice emerge   copyright 101i3  marti    lt thfr kikc  jr   and that is something that i mus t say to my pbople who o n the worn threshold whieh leads into the palace of justice  in the process of gaining our rightful place we must not he guilty of wrongful deeds  let us not  eek to sati sfy our thirst for freedom by drinking from the cup of bime n le s s a nd hatred   ve must forever conduct our s truggle on the high plane of dignity and diseiplin e   ye must not allow our tive protests to degen e rate into physical violence  again and again we must ri se to the maje stic heights of meding physical fo rce wi th soul for ce  rl he marvelous new tancy whi ch has cn gulfe d the negro community must not lead us to distrust all white people  for ma ...

# %%
keywords
# Out:
# ['``',
#  'I',
#  'HAVE',
#  'A',
#  'DREAM',
#  "''",
#  'Copyright',
#  '1963',
#  'MARTIN',
#  'LtrTHER',
#  'KING',
#  'JR.',
#  'Speooh',
#  'Rev',
#  'MARTIN',
#  'LuTHER',
#  'KING',
#  'At',
#  '``',
#  'March',
#  'vYashington',
#  "''",
#  'I',
#  'happy',
#  'join',
#  'today',
#  'go',
#  'history',
#  'greatesŁt',
#  'demonstration',
#  'freedom',
#  'history',
#  'nation',
#  'Five',
#  'years',
#  'ago',
#  'great',
#  'American',
#  'whose',
#  'holic',
#  'shado·w',
#  'stand',
#  'today',
#  'signed',
#  'Emancipation',
#  'Proclamation',
#  'This',
#  'momen',
#  'tous',
#  'cleeree',
#  'great',
#  'beacon',
#  'light',
#  'hope',
#  'millions',
#  'Negro',
#  'slave·s',
#  'flames',
#  'withering',
#  'injushcc',
#  'It',
#  'came',
#  'joyous',
#  'daybre',
#  'ak',
#  'end',
#  'long',
#  'night',
#  'captivity',
#  'But',
#  '100',
#  'years',
#  'late',
#  '<',
#  'r',
#  'Negro',
#  'still',
#  'noŁt',
#  'fre·e',
#  'One',
#  'dred',
#  'years',
#  'later',
#  '1i.fe',
#  'Negro',
#  'still',
#  'badly',
#  'erippled',
#  'manacles',
#  's-tŁgrPg-ation',
#  'chains',
#  'discriminatio11',
#  'One',
#  'hnndred',
#  'years',
#  'later',
#  'Ne',
#  'gro',
#  'live·s',
#  'lone',
#  'Jy',
#  "''",
#  'poverty',
#  'mids1t',
#  'va1S1t',
#  'ooean',
#  'matE',
#  '>',
#  '.rial',
#  'prospc·rity',
#  'Out',
#  '>',
#  'hundred',
#  'years',
#  'later',
#  'egro',
#  'still',
#  'iu',
#  'o.f',
#  'Ame·rican',
#  'find',
#  'exile',
#  'land',
#  'So',
#  'wo',
#  "''",
#  "'",
#  '<',
#  "'",
#  'come',
#  "hf'rP",
#  'torlay',
#  'r1r.amatize',
#  'hameful',
#  'condition',
#  'In',
#  'sense',
#  "'ve",
#  'come',
#  'nation',
#  "'s",
#  'capital',
#  'cash',
#  'eheck',
#  'Whrn',
#  'a.',
#  'rebit',
#  'ects',
#  'Re',
#  'publie',
#  'wrote',
#  'magnificent',
#  'wonls',
#  'Constitution',
#  'a.nd',
#  'Declaration',
#  'o1',
#  'Independence',
#  'we·re',
#  'signing·',
#  "promiss'Cl",
#  '<',
#  'ry',
#  'note',
#  'eve·ry',
#  'American',
#  'wa',
#  "''",
#  'fall',
#  'heir',
#  "'",
#  "I'his",
#  'te',
#  'promise',
#  'nwn-yc',
#  'bla',
#  'ek',
#  'men',
#  'we11',
#  'white',
#  'rmm-wonld',
#  'g1mnmtPt',
#  "'d",
#  'unalienable',
#  'rights',
#  'life',
#  'liherty',
#  'l',
#  'l',
#  'pnrsni1',
#  "ha.ppine'Ss",
#  'It',
#  'obvious',
#  'today',
#  'tha.t',
#  'Amcri',
#  '·a',
#  'lms',
#  '<',
#  'lcfaulted',
#  'promissory',
#  'note',
#  'far',
#  'hP',
#  '>',
#  'r',
#  'citi7.ens',
#  'co.Jo',
#  'r',
#  'arr',
#  'concP',
#  'rned',
#  'Instead',
#  'honoring',
#  'ih1s',
#  'sacn',
#  "'d",
#  'ohli',
#  'gation',
#  'America',
#  'ha.s',
#  'given',
#  'Nngro',
#  'p0ople',
#  'bad',
#  'check',
#  'check',
#  'come',
#  'back',
#  'marked',
#  '``',
#  'insufficient',
#  'fnnds',
#  "''",
#  'But',
#  'refus.e',
#  'helieve',
#  'bank',
#  'justice',
#  'bankrupt',
#  'We',
#  'rp.fnse',
#  't.ha.t',
#  'insufficient',
#  'fuwls',
#  'grea.t',
#  'vaults',
#  'opportunity',
#  'orf',
#  'nation',
#  'So',
#  "'ve",
#  'come',
#  'cash',
#  'check',
#  'check',
#  'give',
#  'ns',
#  'upon',
#  'oemand',
#  'rirhes',
#  'freedom',
#  's·ecurity',
#  'justice',
#  '\\Ve',
#  'haYe',
#  'a.bo',
#  'come',
#  'hallowed',
#  'spot',
#  'remind',
#  'Ame.rica',
#  'fipJ·ce',
#  'urgency',
#  "'",
#  "l'hi",
#  '-',
#  'time',
#  "l'llgagc",
#  'luxury',
#  'cooling',
#  't.ake',
#  'quilizing',
#  'dmg',
#  'graduali',
#  'm.',
#  'Now',
#  'time',
#  'make',
#  'real',
#  'democracy',
#  'Now',
#  'time',
#  'rise',
#  'dark',
#  'nnll',
#  'clrsolate',
#  'valley',
#  'segregation',
#  '.unlit',
#  'path',
#  'racial',
#  'justi',
#  '<',
#  '·P',
#  'Now',
#  'time',
#  'li.ft',
#  'uation',
#  'quicksands',
#  'raeial',
#  'injustice',
#  'solid',
#  'r',
#  'ek',
#  'brotherhood',
#  'Xow',
#  't.he',
#  'time',
#  'mak0',
#  'justice',
#  'reality',
#  'God',
#  "'s",
#  'children',
#  'It',
#  'would',
#  'fatal',
#  'nation',
#  'look',
#  'urgency',
#  'moment',
#  'This',
#  'swelt.ering',
#  'summer',
#  'i\\eg',
#  'ro',
#  "'s",
#  'legitimate',
#  'disconte.nt',
#  'pass',
#  '.an',
#  'invigorating',
#  'autumn',
#  'freedom',
#  'equality',
#  '-1963',
#  'md',
#  'beginning',
#  'Tho',
#  '>',
#  'se',
#  'hope',
#  'tl1e',
#  'Xegro',
#  'needed',
#  'hlow',
#  'steam',
#  "l'Olltent",
#  'ha\\·e',
#  'ruoP',
#  'awakening',
#  'na',
#  'tion',
#  'return1',
#  "'",
#  '1',
#  'usua.I',
#  "'",
#  "l'here",
#  "11eitht'T",
#  'rest',
#  'tranquility',
#  'Ame.rica',
#  'Negro',
#  'granted',
#  'citizenship',
#  'rights',
#  'The',
#  'whirlwinds',
#  'revolt',
#  'continue',
#  'shake',
#  'tions',
#  'onr',
#  'nation',
#  'bright',
#  'days',
#  'justice',
#  'emerge',
#  'Copyright',
#  '101i3',
#  'MARTI',
#  '-',
#  '<',
#  'Lt',
#  'THFR',
#  'KIKc',
#  'JR.',
#  'And',
#  'something',
#  'I',
#  'mus.t',
#  'say',
#  'pBople',
#  'o.n',
#  'worn',
#  'threshold',
#  'whieh',
#  'leads',
#  'palace',
#  'justice',
#  'In',
#  'process',
#  'gaining',
#  'rightful',
#  'place',
#  'must',
#  'guilty',
#  'wrongful',
#  'deeds',
#  'Let',
#  'us',
#  '``',
#  'eek',
#  'sati',
#  'sfy',
#  'thirst',
#  'freedom',
#  'drinking',
#  'cup',
#  'biMe·n',
#  'le·s',
#  'a.nd',
#  'hatred',
#  '\\Ve',
#  'must',
#  'forever',
#  'conduct',
#  's.truggle',
#  'high',
#  'plane',
#  'dignity',
#  'diseiplin',
#  'e.',
#  '\\Ye',
#  'must',
#  'allow',
#  'tive',
#  'protests',
#  'degen',
#  'e·rate',
#  'physical',
#  'violence',
#  'Again',
#  'must',
#  'ri',
#  'se',
#  'maje',
#  'stic',
#  'heights',
#  'meding',
#  'physical',
#  'fo.rce',
#  'wi.th',
#  'soul',
#  'for-ce',
#  "rl'he",
#  'marvelous',
#  'new',
#  'tancy',
#  'whi-ch',
#  'cn.gulfE',
#  '>',
#  'Negro',
#  'community',
#  'must',
#  'lead',
#  'us',
#  'distrust',
#  'white',
#  'people',
#  'many',
#  'white',
#  'hrotlwrs',
#  'evidcnccŁJ',
#  'the·ir',
#  'prese.nce',
#  'today',
#  'eome',
#  'realize',
#  'tha.t',
#  'destiny',
#  'tied',
#  'They',
#  'come',
#  're.alize',
#  'freedom',
#  'extt·ieably',
#  'hound',
#  't.o',
#  'fre.room',
#  '\\\\',
#  "'",
#  'e',
#  'walk',
#  'alone',
#  'And',
#  'walk',
#  'must',
#  'make',
#  'pledge',
#  'shall',
#  'always',
#  'march',
#  'ahcarl',
#  'We',
#  'turn',
#  'hack',
#  'There',
#  '.asking',
#  'rlevotee·s',
#  'civil',
#  'rights',
#  '``',
#  'When',
#  'sa.t.isfied',
#  '1',
#  "''",
#  '\\Ve',
#  'never',
#  'satisfied',
#  'l',
#  '<',
#  'mg',
#  'ns',
#  'Negro',
#  'victim',
#  'unspeakable',
#  'horrors',
#  'police',
#  'brutality',
#  '\\\\',
#  '!',
#  'e',
#  'c.an',
#  'never',
#  'satisfied',
#  'long',
#  'bodie',
#  'heavy',
#  'fatigue',
#  'travel',
#  'gain',
#  'lodging',
#  'motels',
#  'highways',
#  'hotels',
#  'cities',
#  '\\Ve',
#  'satisfied',
#  'long',
#  'Negro',
#  "'s",
#  'basic',
#  'mobility',
#  'smaller',
#  'ghetto',
#  'Larger',
#  'one',
#  'We',
#  '<',
#  '·an',
#  'never',
#  'satis',
#  'fie',
#  '<',
#  'l',
#  'long',
#  'children',
#  'stripped',
#  'adulthood',
#  'robbed',
#  'dignity',
#  's1gns',
#  '``',
#  'For',
#  "\\'TJ1ites",
#  'Only',
#  "''",
#  'Copyright',
#  '1963.',
#  '\\',
#  'fAR',
#  'TI',
#  '!',
#  '\\',
#  "'",
#  'LUTHF.R',
#  'KING',
#  'JR.',
#  'We',
#  'oannot',
#  'satisfied',
#  '3lS',
#  'long',
#  'Negro',
#  'sissippi',
#  'vote',
#  'Negro',
#  'New',
#  'York',
#  'believes',
#  'nothing',
#  'vote',
#  'No',
#  'satisfied',
#  'nOit',
#  'fied',
#  'justice',
#  'rolls',
#  'like',
#  'waters',
#  'righteousness',
#  'like',
#  'mig·hty',
#  'stream',
#  'I',
#  'unmindful',
#  'come',
#  'great',
#  'trials',
#  't.ribulation',
#  'Some',
#  'eome',
#  'fresh',
#  'narrow',
#  'jail',
#  '<',
#  '!',
#  '.ells',
#  'S',
#  'ome',
#  'oome',
#  'are-as',
#  'quest',
#  'freedom',
#  'left',
#  'battered',
#  'storm.s',
#  'persecution',
#  'staggered',
#  '1hf',
#  "'",
#  'winds',
#  'police',
#  'brutality',
#  'You',
#  'veterans',
#  'erea',
#  'tive',
#  'suffering',
#  'Continue',
#  'work',
#  'faith',
#  'un-earned',
#  'suffering',
#  'redemptive',
#  'Go',
#  'hack',
#  'Mississippi',
#  'go',
#  'back',
#  't.o',
#  'harna.',
#  'go',
#  'back',
#  'South',
#  'Carolina',
#  'go',
#  'back',
#  'Georgia',
#  'go',
#  'hack',
#  'Louisiana',
#  'go',
#  'back',
#  'slums',
#  'ghet.tos',
#  "'\\",
#  'orthern',
#  'citie·s',
#  'knowing',
#  'somehow',
#  'situation',
#  'oan',
#  'changed',
#  'Let',
#  'us',
#  'wallow',
#  'valley',
#  'ot',
#  "'",
#  'des.pai·r',
#  '·',
#  'I',
#  'say',
#  'today',
#  'friends',
#  'though',
#  'even',
#  'though',
#  'face',
#  'today',
#  'tomorrow',
#  'I',
#  'still',
#  'dream',
#  'It',
#  'dream',
#  'deeply',
#  'rooted',
#  'American',
#  'dl',
#  "'",
#  'e.am',
#  'I',
#  'dream',
#  'one',
#  'day',
#  '11ation',
#  'rise',
#  'live',
#  'h·ue',
#  'meaning',
#  'creed',
#  '``',
#  "''",
#  "'",
#  'e',
#  'hold',
#  'truths',
#  'self-evident',
#  'men',
#  'created',
#  'equal',
#  "''",
#  'I',
#  'dream',
#  'one',
#  'day',
#  'red',
#  'hills',
#  'Geo·rgia',
#  'former',
#  'slan',
#  "'",
#  't.lw',
#  '-',
#  'ons',
#  'forml',
#  "'",
#  'r',
#  'able',
#  'sit',
#  'do\\vn',
#  'together',
#  'table',
#  'brothehood',
#  'I',
#  'dream',
#  'one',
#  'day',
#  'even',
#  'state',
#  'state',
#  'sweltering',
#  'h',
#  'eat',
#  'inJustice',
#  'Copyright',
#  '19o.l',
#  'MARTI',
#  "'\\1",
#  'LuTHER',
#  'KING',
#  'JR.',
#  "l'iweltering",
#  'heat',
#  'oppression',
#  '!',
#  "'ormed",
#  'oasis',
#  'fre·edom',
#  'justice',
#  'I',
#  'dream',
#  'four',
#  'little',
#  'chi1dre',
#  '!',
#  'Il',
#  'one',
#  'day',
#  'live',
#  'nation',
#  '\\Vhere',
#  'judged',
#  'color',
#  'skin',
#  'conte·nt',
#  'ir',
#  'cha.ra',
#  '{',
#  '!',
#  '.te',
#  'r.l',
#  'I',
#  'dream',
#  'I',
#  'dream',
#  'tha',
#  'one',
#  'day',
#  'AJ',
#  'abama',
#  'vicious',
#  'racists',
#  'governor',
#  'lips',
#  'dripping',
#  'words',
#  'interposition',
#  'nullification',
#  'one',
#  'day',
#  'right',
#  'Alabama',
#  'little',
#  'black',
#  'boys',
#  'a.nd',
#  'black',
#  'g.·ids',
#  'abl',
#  'e',
#  'join',
#  'hands',
#  'lit.tle',
#  'white',
#  'boy',
#  "'s",
#  'white',
#  'girls',
#  'sisters',
#  'anrl',
#  'brothers',
#  'I',
#  'dre·am',
#  'today',
#  'I',
#  'dream',
#  'one',
#  'day',
#  'every',
#  'vaUey',
#  'shall',
#  'exalted',
#  'hill',
#  'mountain',
#  '.ohall',
#  'made',
#  'lov.-',
#  "'",
#  "l'he",
#  'rough',
#  'places',
#  'made',
#  'plain',
#  'aad',
#  'crooked',
#  'IJlaces',
#  'made',
#  'straight',
#  '.And',
#  'Lord',
#  'shall',
#  'revealed',
#  'flesh',
#  'shall',
#  'see',
#  'together',
#  'This',
#  'onr',
#  'hope',
#  'This',
#  'faith',
#  'I',
#  'go',
#  'back',
#  'thC',
#  "'",
#  'South',
#  'With',
#  'faith',
#  'hew',
#  'mountain',
#  'de·spair',
#  'stone',
#  'hope',
#  'With',
#  'fait.h',
#  ',·ill',
#  'ahle',
#  'transform',
#  'jangling',
#  'discords',
#  'nation',
#  'beautiful',
#  'symphony',
#  '<',
#  'f',
#  'brotherhood',
#  'With',
#  'faith',
#  'able',
#  'work',
#  'togother',
#  'pray',
#  'together',
#  'struggle',
#  'together',
#  'go',
#  'jail',
#  'togethN',
#  'stand',
#  'freedom',
#  'together',
#  'knowing',
#  'fnŁe',
#  'one',
#  'd.ay',
#  'This',
#  'IH',
#  "'",
#  'clay',
#  'God',
#  "'s",
#  'children',
#  'nble',
#  'sing',
#  'new',
#  'meaning',
#  '``',
#  'My',
#  'country',
#  "'t",
#  'thee',
#  'land',
#  'libt',
#  '>',
#  "l't.y",
#  'thee',
#  'I',
#  'Land',
#  'fathers',
#  'died',
#  'land',
#  'th',
#  '<',
#  "'",
#  'pilgrim',
#  "'s",
#  'pride',
#  'every',
#  'mountain',
#  'side',
#  'let',
#  'freedom',
#  'ring',
#  "''",
#  'And',
#  'America',
#  'a.',
#  'great',
#  'nation',
#  'mn',
#  ':..t',
#  'become',
#  'true',
#  'So',
#  'let',
#  'freedom',
#  'ring',
#  'tlH',
#  "'",
#  'prodigious',
#  'hilltops',
#  'New',
#  'Hampshire',
#  ...]
